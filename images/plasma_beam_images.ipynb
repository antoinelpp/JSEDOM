# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
# Out:
# /home/tavant/venv/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/tavant/venv/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def maxw(v,s,vd):
    return np.exp(-(v-vd)**2/s)

# %%
vmax = 1e7
Nbins = 500
vs = np.linspace(-vmax/5,vmax,Nbins)

# %%
s = 0.5e6**2

vb = 5e6

# %%
plt.plot(vs/1e3, maxw(vs,s,0)+maxw(vs,s,vb))
plt.title("Velocity distribution of the electrons")
plt.xlabel("$V [km/s]$")
plt.ylabel("$f_e(V)/f_e(0) [su]$")
plt.savefig("plasma_beam_f_v.png", dpi=900)

# %%
# Out:
# 1.0
